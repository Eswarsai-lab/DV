# %%
import pandas as pd
import plotly.express as px

# === Load Your Dataset ===
# Example: load CSV file
df = pd.read_csv("/content/manufacturing_production_efficiency.csv")   # 👈 replace with your dataset path

# Detect categorical and continuous columns
categorical_cols = df.select_dtypes(include=["object", "category"]).columns.tolist()
continuous_cols = df.select_dtypes(include=["number"]).columns.tolist()

# Print detected columns (for reference)
print("Categorical columns:", categorical_cols)
print("Continuous columns:", continuous_cols)

# Ensure we have at least 2 categorical and 1 continuous column
if len(categorical_cols) >= 2 and len(continuous_cols) > 0:
    cat1, cat2 = categorical_cols[:2]   # First two categorical columns
    value_col = continuous_cols[0]      # First numeric column

    fig = px.treemap(
        df,
        path=[cat1, cat2],               # Hierarchical levels
        values=value_col,                # Size of boxes
        title=f"TreeMap of {cat1} > {cat2} sized by {value_col}",
        color=value_col,
        color_continuous_scale="Viridis"
    )
    fig.show()
else:
    print("\n[Skipped TreeMap] Need at least 2 categorical columns and 1 continuous column.")
# Out:
# Categorical columns: ['Order Date', 'Shift', 'Machine', 'Operator']
# Continuous columns: ['Production_Time', 'Units_Produced', 'Defects', 'Downtime_Minutes', 'Energy_Consumption_kWh', 'Efficiency_Score']
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="927d3284-a826-489a-bb86-3c9c2751009b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("927d3284-a826-489a-bb86-3c9c2751009b")) {                    Plotly.newPlot(                        "927d3284-a826-489a-bb86-3c9c2751009b",                        [{"branchvalues":"total","customdata":[[9.3],[4.45],[5.15],[5.61],[6.91],[6.24],[9.58],[4.42],[9.09],[8.25],[7.32],[6.52],[4.17],[6.63],[8.03],[5.97],[9.89],[9.16],[8.97],[9.79],[6.74],[9.05],[5.17],[6.469999999999999],[8.2],[4.83],[8.29],[4.25],[6.39],[6.6],[8.46],[5.51],[6.57],[9.49],[4.56],[7.83],[7.43],[9.97],[6.82],[7.43],[5.83],[6.37],[9.07],[5.25],[8.03],[6.15],[4.49],[7.77],[6.38],[4.3],[7.47],[4.93],[9.03],[5.820000000000001],[5.63],[4.8],[4.35],[6.65],[5.44],[9.61],[7.1],[7.94],[6.61],[8.38],[7.4],[4.95],[4.72],[4.55],[4.56],[7.0],[8.61],[4.26],[5.680000000000001],[8.49],[9.72],[5.98],[7.32],[9.88],[5.52],[5.77],[5.94],[4.82],[5.78],[5.54],[7.67],[4.03],[5.17],[4.43],[9.32],[5.5],[4.23],[7.22],[5.96],[9.82],[5.11],[4.49],[8.13],[5.1],[4.29],[6.05],[7.0],[7.43],[8.61],[4.26],[9.97],[6.82],[5.680000000000001],[9.3],[8.49],[9.72],[5.98],[7.32],[7.43],[9.88],[4.45],[5.83],[5.15],[5.61],[6.91],[6.24],[6.37],[9.07],